# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("housing.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
df.describe().T.style.bar(subset=["mean"], color="#4e4151").background_gradient(subset=["std","50%","max"])
# Out:
# <style type="text/css">
# #T_6e394_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #4e4151 0.1%, transparent 0.1%);
# }
# #T_6e394_row0_col2, #T_6e394_row0_col5, #T_6e394_row0_col7, #T_6e394_row1_col2, #T_6e394_row1_col5, #T_6e394_row1_col7, #T_6e394_row2_col2, #T_6e394_row2_col5, #T_6e394_row2_col7, #T_6e394_row4_col2, #T_6e394_row4_col5, #T_6e394_row6_col2, #T_6e394_row6_col5, #T_6e394_row7_col2, #T_6e394_row7_col5, #T_6e394_row7_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6e394_row1_col1, #T_6e394_row2_col1, #T_6e394_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.1%, #4e4151 0.1%, #4e4151 0.1%, transparent 0.1%);
# }
# #T_6e394_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.1%, #4e4151 0.1%, #4e4151 1.3%, transparent 1.3%);
# }
# #T_6e394_row3_col2, #T_6e394_row3_col5, #T_6e394_row4_col7, #T_6e394_row6_col7 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_6e394_row3_col7 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_6e394_row4_col1, #T_6e394_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.1%, #4e4151 0.1%, #4e4151 0.3%, transparent 0.3%);
# }
# #T_6e394_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.1%, #4e4151 0.1%, #4e4151 0.7%, transparent 0.7%);
# }
# #T_6e394_row5_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_6e394_row5_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_6e394_row5_col7 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_6e394_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.1%, #4e4151 0.1%, #4e4151 100.0%, transparent 100.0%);
# }
# #T_6e394_row8_col2, #T_6e394_row8_col5, #T_6e394_row8_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e394">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e394_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_6e394_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_6e394_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_6e394_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_6e394_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_6e394_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_6e394_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_6e394_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e394_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_6e394_row0_col0" class="data row0 col0" >20640.000000</td>
#       <td id="T_6e394_row0_col1" class="data row0 col1" >-119.569704</td>
#       <td id="T_6e394_row0_col2" class="data row0 col2" >2.003532</td>
#       <td id="T_6e394_row0_col3" class="data row0 col3" >-124.350000</td>
#       <td id="T_6e394_row0_col4" class="data row0 col4" >-121.800000</td>
#       <td id="T_6e394_row0_col5" class="data row0 col5" >-118.490000</td>
#       <td id="T_6e394_row0_col6" class="data row0 col6" >-118.010000</td>
#       <td id="T_6e394_row0_col7" class="data row0 col7" >-114.310000</td>
#     </tr>
#     <tr>
#       <th id="T_6e394_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_6e394_row1_col0" class="data row1 col0" >20640.000000</td>
#       <td id="T_6e394_row1_col1" class="data row1 col1" >35.631861</td>
#       <td id="T_6e394_row1_col2" class="data row1 col2" >2.135952</td>
#       <td id="T_6e394_row1_col3" class="data row1 col3" >32.540000</td>
#       <td id="T_6e394_row1_col4" class="data row1 col4" >33.930000</td>
#       <td id="T_6e394_row1_col5" class="data row1 col5" >34.260000</td>
#       <td id="T_6e394_row1_col6" class="data row1 col6" >37.710000</td>
#       <td id="T_6e394_row1_col7" class="data row1 col7" >41.950000</td>
#     </tr>
#     <tr>
#       <th id="T_6e394_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_6e394_row2_col0" class="data row2 col0" >20640.000000</td>
#       <td id="T_6e394_row2_col1" class="data row2 col1" >28.639486</td>
#       <td id="T_6e394_row2_col2" class="data row2 col2" >12.585558</td>
#       <td id="T_6e394_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_6e394_row2_col4" class="data row2 col4" >18.000000</td>
#       <td id="T_6e394_row2_col5" class="data row2 col5" >29.000000</td>
#       <td id="T_6e394_row2_col6" class="data row2 col6" >37.000000</td>
#       <td id="T_6e394_row2_col7" class="data row2 col7" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6e394_level0_row3" class="row_heading level0 row3" >total_rooms</th>
#       <td id="T_6e394_row3_col0" class="data row3 col0" >20640.000000</td>
#       <td id="T_6e394_row3_col1" class="data row3 col1" >2635.763081</td>
#       <td id="T_6e394_row3_col2" class="data row3 col2" >2181.615252</td>
#       <td id="T_6e394_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_6e394_row3_col4" class="data row3 col4" >1447.750000</td>
#       <td id="T_6e394_row3_col5" class="data row3 col5" >2127.000000</td>
#       <td id="T_6e394_row3_col6" class="data row3 col6" >3148.000000</td>
#       <td id="T_6e394_row3_col7" class="data row3 col7" >39320.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6e394_level0_row4" class="row_heading level0 row4" >total_bedrooms</th>
#       <td id="T_6e394_row4_col0" class="data row4 col0" >20433.000000</td>
#       <td id="T_6e394_row4_col1" class="data row4 col1" >537.870553</td>
#       <td id="T_6e394_row4_col2" class="data row4 col2" >421.385070</td>
#       <td id="T_6e394_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_6e394_row4_col4" class="data row4 col4" >296.000000</td>
#       <td id="T_6e394_row4_col5" class="data row4 col5" >435.000000</td>
#       <td id="T_6e394_row4_col6" class="data row4 col6" >647.000000</td>
#       <td id="T_6e394_row4_col7" class="data row4 col7" >6445.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6e394_level0_row5" class="row_heading level0 row5" >population</th>
#       <td id="T_6e394_row5_col0" class="data row5 col0" >20640.000000</td>
#       <td id="T_6e394_row5_col1" class="data row5 col1" >1425.476744</td>
#       <td id="T_6e394_row5_col2" class="data row5 col2" >1132.462122</td>
#       <td id="T_6e394_row5_col3" class="data row5 col3" >3.000000</td>
#       <td id="T_6e394_row5_col4" class="data row5 col4" >787.000000</td>
#       <td id="T_6e394_row5_col5" class="data row5 col5" >1166.000000</td>
#       <td id="T_6e394_row5_col6" class="data row5 col6" >1725.000000</td>
#       <td id="T_6e394_row5_col7" class="data row5 col7" >35682.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6e394_level0_row6" class="row_heading level0 row6" >households</th>
#       <td id="T_6e394_row6_col0" class="data row6 col0" >20640.000000</td>
#       <td id="T_6e394_row6_col1" class="data row6 col1" >499.539680</td>
#       <td id="T_6e394_row6_col2" class="data row6 col2" >382.329753</td>
#       <td id="T_6e394_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_6e394_row6_col4" class="data row6 col4" >280.000000</td>
#       <td id="T_6e394_row6_col5" class="data row6 col5" >409.000000</td>
#       <td id="T_6e394_row6_col6" class="data row6 col6" >605.000000</td>
#       <td id="T_6e394_row6_col7" class="data row6 col7" >6082.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6e394_level0_row7" class="row_heading level0 row7" >median_income</th>
#       <td id="T_6e394_row7_col0" class="data row7 col0" >20640.000000</td>
#       <td id="T_6e394_row7_col1" class="data row7 col1" >3.870671</td>
#       <td id="T_6e394_row7_col2" class="data row7 col2" >1.899822</td>
#       <td id="T_6e394_row7_col3" class="data row7 col3" >0.499900</td>
#       <td id="T_6e394_row7_col4" class="data row7 col4" >2.563400</td>
#       <td id="T_6e394_row7_col5" class="data row7 col5" >3.534800</td>
#       <td id="T_6e394_row7_col6" class="data row7 col6" >4.743250</td>
#       <td id="T_6e394_row7_col7" class="data r

# %%
sns.distplot(df["median_house_value"],color="#a02933")
plt.axvline(x=df["median_house_value"].mean(), color="#a02933",)

# %% [markdown]
# Handle Missing Value

# %%
missing = df.isnull().sum()
missing = missing[missing >= 0]
missing = missing.sort_values(ascending=False)
missing.plot.bar(color="#a02933")
plt.show()
